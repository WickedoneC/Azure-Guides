# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.20.0 to work with chadwicks_workspace

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "Wick-NoCode"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [9783bee1][32efc9b2-ca7d-41f7-9744-1bfbc4042595], (This step will run and generate new outputs)
# Created step Train and Register Model [9605f91f][5ae0143e-73f7-401c-9373-25b20fc120b1], (This step will run and generate new outputs)
# Submitted PipelineRun 598fa91f-8997-4063-b931-1f2d8acdf95a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/598fa91f-8997-4063-b931-1f2d8acdf95a?wsid=/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourcegroups/first_resource_ml/workspaces/chadwicks_workspace
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 598fa91f-8997-4063-b931-1f2d8acdf95a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/598fa91f-8997-4063-b931-1f2d8acdf95a?wsid=/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourcegroups/first_resource_ml/workspaces/chadwicks_workspace
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: f25bd18c-67f9-44a4-b622-e24d49ccef74
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/f25bd18c-67f9-44a4-b622-e24d49ccef74?wsid=/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourcegroups/first_resource_ml/workspaces/chadwicks_workspace
# StepRun( Prepare Data ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/01 20:26:07 Downloading source code...
# 2021/03/01 20:26:09 Finished downloading source code
# 2021/03/01 20:26:09 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/01 20:26:10 Successfully set up Docker network: acb_default_network
# 2021/03/01 20:26:10 Setting up Docker configuration...
# 2021/03/01 20:26:10 Successfully set up Docker configuration
# 2021/03/01 20:26:10 Logging in to registry: 14debbabbe7d42048ea533db4090b2d1.azurecr.io
# 2021/03/01 20:26:11 Successfully logged into 14debbabbe7d42048ea533db4090b2d1.azurecr.io
# 2021/03/01 20:26:11 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/01 20:26:11 Scanning for dependencies...
# 2021/03/01 20:26:12 Successfully scanned dependencies
# 2021/03/01 20:26:12 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# StepRun( Prepare Data ) Status: Running
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/18 : USER root
#  ---> Running in 18f8d050fa8d
# Removing intermediate container 18f8d050fa8d
#  ---> 403b518b5c5c
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in a8f77f33fe10
# Removing intermediate container a8f77f33fe10
#  ---> b88e93714f83
# Step 4/18 : WORKDIR /
#  ---> Running in 33dd3faf2db9
# Removing intermediate container 33dd3faf2db9
#  ---> ff9b2e69a408
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d4af73b08e22
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 80ed8161157c
# Removing intermediate container 80ed8161157c
#  ---> 5bdd25a5234b
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 60311946b8b2
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 784edd966a59
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##5        |  25%
# mkl-2019.4           | 204.1 MB  | ##8        |  29%
# mkl-2019.4           | 204.1 MB  | ###2       |  32%
# mkl-2019.4           | 204.1 MB  | ###6       |  37%
# mkl-2019.4           | 204.1 MB  | ####       |  41%
# mkl-2019.4           | 204.1 MB  | ####5      |  45%
# mkl-2019.4           | 204.1 MB  | ####9      |  50%
# mkl-2019.4           | 204.1 MB  | #####3     |  54%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######1    |  62%
# mkl-2019.4           | 204.1 MB  | ######5    |  66%
# mkl-2019.4           | 204.1 MB  | ######9    |  69%
# mkl-2019.4           | 204.1 MB  | #######3   |  73%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########   |  80%
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########9  |  90%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #5         |  16%
# python-3.6.2         | 27.0 MB   | ####6      |  47%
# python-3.6.2         | 27.0 MB   | ########   |  80%
# python-3.6.2         | 27.0 MB   | #########9 |  99%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ######3    |  63%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #9         |  20%
# icu-58.2             | 22.7 MB   | #####2     |  53%
# icu-58.2             | 22.7 MB   | ########9  |  90%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ####8      |  49%
# gst-plugins-base-1.1 | 6.3 MB    | #########8 |  98%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | #          |  10%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ##7        |  28%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########5  |  86%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #          |  10%
# pandas-1.1.3         | 10.5 MB   | ####7      |  47%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | #######1   |  72%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 6          |   6%
# qt-5.9.6             | 86.7 MB   | #5         |  15%
# qt-5.9.6             | 86.7 MB   | ##4        |  25%
# qt-5.9.6             | 86.7 MB   | ###4       |  35%
# qt-5.9.6             | 86.7 MB   | ####4      |  44%
# qt-5.9.6             | 86.7 MB   | #####2     |  53%
# qt-5.9.6             | 86.7 MB   | ######     |  61%
# qt-5.9.6             | 86.7 MB   | ######8    |  68%
# qt-5.9.6             | 86.7 MB   | #######6   |  77%
# qt-5.9.6             | 86.7 MB   | ########5  |  86%
# qt-5.9.6             | 86.7 MB   | #########3 |  94%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | #9         |  19%
# scipy-1.5.2          | 18.5 MB   | #####3     |  53%
# scipy-1.5.2          | 18.5 MB   | #########8 |  98%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####2      |  42%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.1s5bf1no.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.20.0
#   Downloading azureml_defaults-1.20.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.11.1-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.20.0
#   Downloading azureml_dataset_runtime-1.20.0-py3-none-any.whl (3.4 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-core~=1.20.0
#   Downloading azureml_core-1.20.0.post1-py3-none-any.whl (2.1 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<31.0.0,>=30.0.0
#   Downloading azureml_dataprep_native-30.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.10.0a,>=1.9.0dev0
#   Downloading azureml_dataprep_rslex-1.9.0-cp36-cp36m-manylinux2010_x86_64.whl (8.5 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 1)) (2.8.1)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 1)) (2020.1)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.6-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.11.0-py2.py3-none-any.whl (127 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.9.0-py2.py3-none-any.whl (59 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.1s5bf1no.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.7.0-py3-none-any.whl (11 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=af587044d191cae00f90688e595cc10db57179ef5ad45bb03636aa8a2b0647b9
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=175a4fd2ecfeaee3cf7a7444642c377d415b9cb70bdf7a33f920d1585fb27306
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=8aa74a0c496333952e865a075009cf413dc98888b108c110a2a48ccd343eef4a
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: dill, liac-arff, PyJWT, chardet, idna, urllib3, requests, pycparser, cffi, cryptography, adal, azureml-model-management-sdk, configparser, portalocker, msal, msal-extensions, azure-core, azure-identity, cloudpickle, azureml-dataprep-native, distro, dotnetcore2, azureml-dataprep-rslex, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, werkzeug, json-logging-py, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-storage, jmespath, backports.weakref, backports.tempfile, websocket-client, docker, jeepney, SecretStorage, pyopenssl, pyasn1, ndg-httpsclient, pathspec, azure-graphrbac, contextlib2, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-mgmt-resource, azureml-core, gunicorn, itsdangerous, MarkupSafe, Jinja2, click, flask, applicationinsights, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.11.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.20.0.post1 azureml-dataprep-2.11.1 azureml-dataprep-native-30.0.0 azureml-dataprep-rslex-1.9.0 azureml-dataset-runtime-1.20.0 azureml-defaults-1.20.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.6 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.9.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 784edd966a59
#  ---> cec80ba7bad9
# Step 9/18 : ENV PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin:$PATH
#  ---> Running in f26e2a4151c7
# Removing intermediate container f26e2a4151c7
#  ---> da23a38e5988
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 67c7d01cad5a
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> b0bcac24f044
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2
#  ---> Running in 633efae6584f
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 633efae6584f
#  ---> 113ee83de442
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2
#  ---> Running in 8741b72b01d7
# Removing intermediate container 8741b72b01d7
#  ---> 0fcafe331d30
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib:$LD_LIBRARY_PATH
#  ---> Running in bbf0d439a954
# Removing intermediate container bbf0d439a954
#  ---> 6aac50c479fd
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> c900c33cc3cd
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 374697d52b38
# Removing intermediate container 374697d52b38
#  ---> bcabc134df64
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 6861312f1e90
# Removing intermediate container 6861312f1e90
#  ---> 3a3e7067b6ca
# Step 18/18 : CMD ["bash"]
#  ---> Running in b94bb19c3129
# Removing intermediate container b94bb19c3129
#  ---> 50586f9a1482
# Successfully built 50586f9a1482
# Successfully tagged 14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021/03/01 20:32:35 Successfully executed container: acb_step_0
# 2021/03/01 20:32:35 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/01 20:32:35 Pushing image: 14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest, attempt 1
# The push refers to repository [14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90]
# a5319c01ea0d: Preparing
# 3c6425d6bc02: Preparing
# 652edd0da309: Preparing
# 50c5871251e8: Preparing
# e0d939ec230f: Preparing
# 3597e67f454a: Preparing
# 82891d71992c: Preparing
# 7dcda06ba2aa: Preparing
# b70611332573: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 3597e67f454a: Waiting
# 7dcda06ba2aa: Waiting
# b70611332573: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# 82891d71992c: Waiting
# a5319c01ea0d: Pushed
# 3c6425d6bc02: Pushed
# 50c5871251e8: Pushed
# 652edd0da309: Pushed
# 3597e67f454a: Pushed
# 82891d71992c: Pushed
# 7dcda06ba2aa: Pushed
# b70611332573: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# e342e7653d41: Pushed
# 088c5f014be3: Pushed
# 1a1a19626b20: Pushed
# 0c7d6f1219f0: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
#
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
# e0d939ec230f: Pushed
# latest: digest: sha256:8ff5cd7347c5c70f569a00484e94f11ffecae9f1ce949f926327b11e7778e333 size: 4721
# 2021/03/01 20:35:46 Successfully pushed image: 14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021/03/01 20:35:46 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 383.851889)
# 2021/03/01 20:35:46 Populating digests for step ID: acb_step_0...
# 2021/03/01 20:35:48 Successfully populated digests for step ID: acb_step_0
# 2021/03/01 20:35:48 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 190.944827)
# 2021/03/01 20:35:48 The following dependencies were found:
# 2021/03/01 20:35:48
# - image:
#     registry: 14debbabbe7d42048ea533db4090b2d1.azurecr.io
#     repository: azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
#     tag: latest
#     digest: sha256:8ff5cd7347c5c70f569a00484e94f11ffecae9f1ce949f926327b11e7778e333
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
#
# Run ID: ch3 was successful after 9m41s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_2f875139f5189959351cbae8091c7a6d71defabfe7b0bd378e16d920a391d991_d.txt
# ========================================================================================================================
# 2021-03-01T20:37:44Z Starting output-watcher...
# 2021-03-01T20:37:44Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-01T20:37:44Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-03-01T20:37:44Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 1d002fae4472: Pulling fs layer
# 573c052f4d14: Pulling fs layer
# 969e02f15ee7: Pulling fs layer
# 519fc2f18894: Pulling fs layer
# 66c5d6b68872: Pulling fs layer
# 0e0e1789675f: Pulling fs layer
# 3a68d7493d03: Pulling fs layer
# f6305399108a: Pulling fs layer
# 0d20e55ac5c6: Pulling fs layer
# d54d011de0e3: Waiting
# 1d002fae4472: Waiting
# 573c052f4d14: Waiting
# 969e02f15ee7: Waiting
# 519fc2f18894: Waiting
# 66c5d6b68872: Waiting
# 0e0e1789675f: Waiting
# 3a68d7493d03: Waiting
# f6305399108a: Waiting
# 0d20e55ac5c6: Waiting
# d584ef274e55: Waiting
# 05895bb28c18: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# baf7ab26f516: Waiting
# b177109c9d16: Waiting
# 181182e3c9cf: Waiting
# 59cea07bb66c: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 573c052f4d14: Verifying Checksum
# 573c052f4d14: Download complete
# 1d002fae4472: Verifying Checksum
# 1d002fae4472: Download complete
# 519fc2f18894: Verifying Checksum
# 519fc2f18894: Download complete
# 969e02f15ee7: Verifying Checksum
# 969e02f15ee7: Download complete
# 0e0e1789675f: Verifying Checksum
# 0e0e1789675f: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# 3a68d7493d03: Verifying Checksum
# 3a68d7493d03: Download complete
# d887158cc58c: Pull complete
# f6305399108a: Download complete
# 05895bb28c18: Pull complete
# 0d20e55ac5c6: Verifying Checksum
# 0d20e55ac5c6: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# 66c5d6b68872: Verifying Checksum
# 66c5d6b68872: Download complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# 1d002fae4472: Pull complete
# 573c052f4d14: Pull complete
# 969e02f15ee7: Pull complete
# 519fc2f18894: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_2f875139f5189959351cbae8091c7a6d71defabfe7b0bd378e16d920a391d991_d.txt
# ===============================================================================================================
# [2021-03-01T20:39:13.632967] Entering job preparation.
# [2021-03-01T20:39:15.843899] Starting job preparation.
# [2021-03-01T20:39:15.843955] Extracting the control code.
# [2021-03-01T20:39:15.869821] fetching and extracting the control code on master node.
# [2021-03-01T20:39:15.870094] Starting extract_project.
# [2021-03-01T20:39:15.870288] Starting to extract zip file.
# [2021-03-01T20:39:16.920022] Finished extracting zip file.
# [2021-03-01T20:39:17.198189] Using urllib.request Python 3.0 or later
# [2021-03-01T20:39:17.198264] Start fetching snapshots.
# [2021-03-01T20:39:17.198318] Start fetching snapshot.
# [2021-03-01T20:39:17.198340] Retrieving project from snapshot: a765b0f5-9696-4fb0-9376-0038f05aea0d
# Starting the daemon thread to refresh tokens in background for process with pid = 50
# [2021-03-01T20:39:17.584765] Finished fetching snapshot.
# [2021-03-01T20:39:17.584799] Finished fetching snapshots.
# [2021-03-01T20:39:17.584818] Finished extract_project.
# [2021-03-01T20:39:17.605661] Finished fetching and extracting the control code.
# [2021-03-01T20:39:17.610308] downloadDataStore - Download from datastores if requested.
# [2021-03-01T20:39:17.612693] Start run_history_prep.
# [2021-03-01T20:39:17.722485] Entering context manager injector.
# Acquired lockfile /tmp/f25bd18c-67f9-44a4-b622-e24d49ccef74-datastore.lock to downloading input data references
# [2021-03-01T20:39:18.463127] downloadDataStore completed
# [2021-03-01T20:39:18.467270] Job preparation is complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/01 20:39:19 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/03/01 20:39:19 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2021-03-01T20:39:21.379246] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', '66507f1b-4fb4-48ca-9378-8d3550afdd54', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/chadwicks_workspace/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/mounts/workspaceblobstore/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/prepped_data_folder'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 106
# [2021-03-01T20:39:23.639632] Entering Run History Context Manager.
# [2021-03-01T20:39:24.424679] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/chadwicks_workspace/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/mounts/workspaceblobstore/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74
# [2021-03-01T20:39:24.425047] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', '66507f1b-4fb4-48ca-9378-8d3550afdd54', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/chadwicks_workspace/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/mounts/workspaceblobstore/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/prepped_data_folder']
# [2021-03-01T20:39:24.425145] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', '66507f1b-4fb4-48ca-9378-8d3550afdd54', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/chadwicks_workspace/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/mounts/workspaceblobstore/azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/prepped_data_folder']
#
# Loading Data...
# Saving Data...
# Starting the daemon thread to refresh tokens in background for process with pid = 106
#
#
# [2021-03-01T20:39:38.762242] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.14325642585754395 seconds
# [2021-03-01T20:39:39.230918] Finished context manager injector.
#
# Streaming azureml-logs/75_job_post-tvmps_2f875139f5189959351cbae8091c7a6d71defabfe7b0bd378e16d920a391d991_d.txt
# ===============================================================================================================
# [2021-03-01T20:39:46.786965] Entering job release
# [2021-03-01T20:39:47.788789] Starting job release
# [2021-03-01T20:39:47.789588] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 345
# [2021-03-01T20:39:47.790344] job release stage : upload_datastore starting...
# [2021-03-01T20:39:47.793214] Entering context manager injector.
# [2021-03-01T20:39:47.800830] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-01T20:39:47.801059] job release stage : execute_job_release starting...
# [2021-03-01T20:39:47.801484] job release stage : copy_batchai_cached_logs starting...
# [2021-03-01T20:39:47.802136] job release stage : copy_batchai_cached_logs completed...
# [2021-03-01T20:39:47.996795] job release stage : upload_datastore completed...
# [2021-03-01T20:39:48.069306] job release stage : send_run_telemetry starting...
# [2021-03-01T20:39:48.088813] job release stage : execute_job_release completed...
# [2021-03-01T20:39:48.310662] get vm size and vm region successfully.
# [2021-03-01T20:39:48.550357] get compute meta data successfully.
# [2021-03-01T20:39:48.729068] post artifact meta request successfully.
# [2021-03-01T20:39:48.783249] upload compute record artifact successfully.
# [2021-03-01T20:39:48.987710] job release stage : send_run_telemetry completed...
# [2021-03-01T20:39:48.987986] Job release is complete
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': 'f25bd18c-67f9-44a4-b622-e24d49ccef74', 'target': 'Wick-NoCode', 'status': 'Completed', 'startTimeUtc': '2021-03-01T20:37:42.173046Z', 'endTimeUtc': '2021-03-01T20:40:00.715864Z', 'properties': {'ContentSnapshotId': 'a765b0f5-9696-4fb0-9376-0038f05aea0d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '32efc9b2-ca7d-41f7-9744-1bfbc4042595', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9783bee1', 'azureml.pipelinerunid': '598fa91f-8997-4063-b931-1f2d8acdf95a', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '66507f1b-4fb4-48ca-9378-8d3550afdd54'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Wick-NoCode', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': '66507f1b-4fb4-48ca-9378-8d3550afdd54', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_c783a5c2ab4cc46496d2d299e0acf4f2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://chadwicksworks6696804822.blob.co ...
# StepRunId: f07ab33b-c521-4cdd-ad84-d947f49803a1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/f07ab33b-c521-4cdd-ad84-d947f49803a1?wsid=/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourcegroups/first_resource_ml/workspaces/chadwicks_workspace
# StepRun( Train and Register Model ) Status: NotStarted
# StepRun( Train and Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_6a67e927c46fa0f83f1baffd12ae8e82e125919da2d14896bcaefe182c34e771_d.txt
# ========================================================================================================================
# 2021-03-01T20:44:23Z Starting output-watcher...
# 2021-03-01T20:44:23Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-01T20:44:24Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-03-01T20:44:24Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
# be8ec4e48d7f: Already exists
# 33b8b485aff0: Already exists
# d887158cc58c: Already exists
# 05895bb28c18: Already exists
# baf7ab26f516: Already exists
# 181182e3c9cf: Already exists
# d584ef274e55: Already exists
# c445dda55407: Already exists
# 699b75ff4717: Already exists
# b177109c9d16: Already exists
# 59cea07bb66c: Already exists
# d54d011de0e3: Already exists
# 1d002fae4472: Pulling fs layer
# 573c052f4d14: Pulling fs layer
# 969e02f15ee7: Pulling fs layer
# 519fc2f18894: Pulling fs layer
# 66c5d6b68872: Pulling fs layer
# 0e0e1789675f: Pulling fs layer
# 3a68d7493d03: Pulling fs layer
# f6305399108a: Pulling fs layer
# 0d20e55ac5c6: Pulling fs layer
# 519fc2f18894: Waiting
# 66c5d6b68872: Waiting
# 0e0e1789675f: Waiting
# 3a68d7493d03: Waiting
# f6305399108a: Waiting
# 0d20e55ac5c6: Waiting
# 1d002fae4472: Verifying Checksum
# 1d002fae4472: Download complete
# 573c052f4d14: Verifying Checksum
# 573c052f4d14: Download complete
# 969e02f15ee7: Verifying Checksum
# 969e02f15ee7: Download complete
# 1d002fae4472: Pull complete
# 573c052f4d14: Pull complete
# 969e02f15ee7: Pull complete
# 0e0e1789675f: Verifying Checksum
# 0e0e1789675f: Download complete
# 519fc2f18894: Download complete
# 519fc2f18894: Pull complete
# 3a68d7493d03: Verifying Checksum
# 3a68d7493d03: Download complete
# f6305399108a: Verifying Checksum
# f6305399108a: Download complete
# 0d20e55ac5c6: Verifying Checksum
# 0d20e55ac5c6: Download complete
# 66c5d6b68872: Verifying Checksum
# 66c5d6b68872: Download complete
# 66c5d6b68872: Pull complete
# 0e0e1789675f: Pull complete
# 3a68d7493d03: Pull complete
# f6305399108a: Pull complete
# 0d20e55ac5c6: Pull complete
# Digest: sha256:8ff5cd7347c5c70f569a00484e94f11ffecae9f1ce949f926327b11e7778e333
# Status: Downloaded newer image for 14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 14debbabbe7d42048ea533db4090b2d1.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021-03-01T20:45:08Z Check if container f07ab33b-c521-4cdd-ad84-d947f49803a1 already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_6a67e927c46fa0f83f1baffd12ae8e82e125919da2d14896bcaefe182c34e771_d.txt
# ===============================================================================================================
# [2021-03-01T20:45:22.928116] Entering job preparation.
# [2021-03-01T20:45:24.886790] Starting job preparation.
# [2021-03-01T20:45:24.886827] Extracting the control code.
# [2021-03-01T20:45:24.916670] fetching and extracting the control code on master node.
# [2021-03-01T20:45:24.916722] Starting extract_project.
# [2021-03-01T20:45:24.916778] Starting to extract zip file.
# [2021-03-01T20:45:25.981818] Finished extracting zip file.
# [2021-03-01T20:45:26.213080] Using urllib.request Python 3.0 or later
# [2021-03-01T20:45:26.213147] Start fetching snapshots.
# [2021-03-01T20:45:26.213208] Start fetching snapshot.
# [2021-03-01T20:45:26.213227] Retrieving project from snapshot: a765b0f5-9696-4fb0-9376-0038f05aea0d
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# [2021-03-01T20:45:26.712457] Finished fetching snapshot.
# [2021-03-01T20:45:26.712505] Finished fetching snapshots.
# [2021-03-01T20:45:26.712516] Finished extract_project.
# [2021-03-01T20:45:26.726987] Finished fetching and extracting the control code.
# [2021-03-01T20:45:26.730849] downloadDataStore - Download from datastores if requested.
# [2021-03-01T20:45:26.732835] Start run_history_prep.
# [2021-03-01T20:45:26.823289] Entering context manager injector.
# Acquired lockfile /tmp/f07ab33b-c521-4cdd-ad84-d947f49803a1-datastore.lock to downloading input data references
# [2021-03-01T20:45:27.498562] downloadDataStore completed
# [2021-03-01T20:45:27.502775] Job preparation is complete.
#
# Streaming azureml-logs/75_job_post-tvmps_6a67e927c46fa0f83f1baffd12ae8e82e125919da2d14896bcaefe182c34e771_d.txt
# ===============================================================================================================
# [2021-03-01T20:45:39.313419] Entering job release
# [2021-03-01T20:45:40.405653] Starting job release
# [2021-03-01T20:45:40.440677] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 148
# [2021-03-01T20:45:40.441177] job release stage : upload_datastore starting...
# [2021-03-01T20:45:40.450000] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-01T20:45:40.450497] job release stage : execute_job_release starting...
# [2021-03-01T20:45:40.451256] job release stage : copy_batchai_cached_logs starting...
# [2021-03-01T20:45:40.451798] Entering context manager injector.
# [2021-03-01T20:45:40.452266] job release stage : copy_batchai_cached_logs completed...
# [2021-03-01T20:45:40.606976] job release stage : upload_datastore completed...
# [2021-03-01T20:45:40.679115] job release stage : execute_job_release completed...
# [2021-03-01T20:45:40.680272] job release stage : send_run_telemetry starting...
# [2021-03-01T20:45:40.936565] get vm size and vm region successfully.
# [2021-03-01T20:45:41.148195] get compute meta data successfully.
# [2021-03-01T20:45:41.322639] post artifact meta request successfully.
# [2021-03-01T20:45:41.370369] upload compute record artifact successfully.
# [2021-03-01T20:45:41.550914] job release stage : send_run_telemetry completed...
# [2021-03-01T20:45:41.551076] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': 'f07ab33b-c521-4cdd-ad84-d947f49803a1', 'target': 'Wick-NoCode', 'status': 'Completed', 'startTimeUtc': '2021-03-01T20:44:24.757291Z', 'endTimeUtc': '2021-03-01T20:45:54.000492Z', 'properties': {'ContentSnapshotId': 'a765b0f5-9696-4fb0-9376-0038f05aea0d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '5ae0143e-73f7-401c-9373-25b20fc120b1', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9605f91f', 'azureml.pipelinerunid': '598fa91f-8997-4063-b931-1f2d8acdf95a', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Wick-NoCode', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f25bd18c-67f9-44a4-b622-e24d49ccef74/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_c783a5c2ab4cc46496d2d299e0acf4f2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_6a67e927c46fa0f83f1baffd12ae8e82e125919da2d14896bcaefe182c34e771_d.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.f07ab33b-c521-4cdd-ad84-d947f49803a1/azureml-logs/55_azureml-execution-tvmps_6a67e927c46fa0f83f1baffd12ae8e82e125919da2d14896bcaefe182c34e771_d.txt?sv=2019-02-02&sr=b&sig=a1fTgD1lle2O7Tfe78HxyrqJpUGiSCvZ8RrdjZVZmUA%3D&st=2021-03-01T20%3A35%3A43Z&se=2021-03-02T04%3A45%3A43Z&sp=r', 'azureml-logs/65_job_prep-tvmps_6a67e927c46f ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '598fa91f-8997-4063-b931-1f2d8acdf95a', 'status': 'Completed', 'startTimeUtc': '2021-03-01T20:25:44.101958Z', 'endTimeUtc': '2021-03-01T20:46:37.043098Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=4dOq3zwQPwcXPUivjmav6xW%2Bf3%2FvO4bZ8g30PD%2BwsT4%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=y0murWdAC3%2Faj5NTnTUOuWK4LroETLQCpQNcTMQzfZ8%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=K0i2RQECSM7qtPCi%2BfTZg964QGsAWpJiMlRMrkplSdc%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r'}, 'submittedBy': 'Chad B'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8995555555555556
# 	 AUC : 0.8849151611085108
# 	 ROC : aml://artifactId/ExperimentRun/dcid.f07ab33b-c521-4cdd-ad84-d947f49803a1/ROC_1614631534.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 11
# 	 Training context : Pipeline
# 	 AUC : 0.8849151611085108
# 	 Accuracy : 0.8995555555555556
#
#
# diabetes_mitigated_20 version: 1
#
#
# diabetes_mitigated_19 version: 1
#
#
# diabetes_mitigated_18 version: 1
#
#
# diabetes_mitigated_17 version: 1
#
#
# diabetes_mitigated_16 version: 1
#
#
# diabetes_mitigated_15 version: 1
#
#
# diabetes_mitigated_14 version: 1
#
#
# diabetes_mitigated_13 version: 1
#
#
# diabetes_mitigated_12 version: 1
#
#
# diabetes_mitigated_11 version: 1
#
#
# diabetes_mitigated_10 version: 1
#
#
# diabetes_mitigated_9 version: 1
#
#
# diabetes_mitigated_8 version: 1
#
#
# diabetes_mitigated_7 version: 1
#
#
# diabetes_mitigated_6 version: 1
#
#
# diabetes_mitigated_5 version: 1
#
#
# diabetes_mitigated_4 version: 1
#
#
# diabetes_mitigated_3 version: 1
#
#
# diabetes_mitigated_2 version: 1
#
#
# diabetes_mitigated_1 version: 1
#
#
# diabetes_unmitigated version: 1
#
#
# diabetes_model version: 10
# 	 Training context : Inline Training
# 	 AUC : 0.8824498916564398
# 	 Accuracy : 0.8984444444444445
#
#
# diabetes_classifier version: 1
#
#
# diabetes_model version: 9
# 	 Training context : Inline Training
# 	 AUC : 0.883347430220409
# 	 Accuracy : 0.8966666666666666
#
#
# diabetes_model version: 8
# 	 Training context : Inline Training
# 	 AUC : 0.8763719588039204
# 	 Accuracy : 0.89
#
#
# diabetes_model version: 7
# 	 Training context : Compute cluster
# 	 AUC : 0.8825894685989483
# 	 Accuracy : 0.8973333333333333
#
#
# diabetes_model version: 6
# 	 Training context : File dataset
# 	 AUC : 0.8568743524381947
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 5
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568509052814499
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 4
# 	 Training context : Parameterized script
# 	 AUC : 0.8484357430717946
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 3
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8484357430717946
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# amlstudio-predict-penguin-clus version: 1
# 	 CreatedByAMLStudio : true
#
#
# amlstudio-predict-diabetes version: 1
# 	 CreatedByAMLStudio : true
#
#
# amlstudio-predict-auto-price version: 1
# 	 CreatedByAMLStudio : true
#
#
# AutoML09f1567f914 version: 1

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: 3c70aca0-187d-4592-9a18-faddb75593b6,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourceGroups/first_resource_ml/providers/Microsoft.MachineLearningServices/workspaces/chadwicks_workspace/PipelineRuns/PipelineSubmit/3c70aca0-187d-4592-9a18-faddb75593b6)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourceGroups/first_resource_ml/providers/Microsoft.MachineLearningServices/workspaces/chadwicks_workspace/PipelineRuns/PipelineSubmit/3c70aca0-187d-4592-9a18-faddb75593b6

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'ac3c3bbb-3b48-4b6c-ba07-a026409792e0'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 598fa91f-8997-4063-b931-1f2d8acdf95a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/598fa91f-8997-4063-b931-1f2d8acdf95a?wsid=/subscriptions/ff78d11c-4cc3-4700-b932-99c18b88b031/resourcegroups/first_resource_ml/workspaces/chadwicks_workspace
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '598fa91f-8997-4063-b931-1f2d8acdf95a', 'status': 'Completed', 'startTimeUtc': '2021-03-01T20:25:44.101958Z', 'endTimeUtc': '2021-03-01T20:46:37.043098Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=4dOq3zwQPwcXPUivjmav6xW%2Bf3%2FvO4bZ8g30PD%2BwsT4%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=y0murWdAC3%2Faj5NTnTUOuWK4LroETLQCpQNcTMQzfZ8%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=K0i2RQECSM7qtPCi%2BfTZg964QGsAWpJiMlRMrkplSdc%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r'}, 'submittedBy': 'Chad B'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: c0f4658e-95cf-4deb-a03b-fc48fe2e9583,
#  Status: Active,
#  Pipeline Id: 3c70aca0-187d-4592-9a18-faddb75593b6,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': '598fa91f-8997-4063-b931-1f2d8acdf95a',
#  'status': 'Completed',
#  'startTimeUtc': '2021-03-01T20:25:44.101958Z',
#  'endTimeUtc': '2021-03-01T20:46:37.043098Z',
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'SDK',
#   'runType': 'SDK',
#   'azureml.parameters': '{}'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=4dOq3zwQPwcXPUivjmav6xW%2Bf3%2FvO4bZ8g30PD%2BwsT4%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=y0murWdAC3%2Faj5NTnTUOuWK4LroETLQCpQNcTMQzfZ8%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://chadwicksworks6696804822.blob.core.windows.net/azureml/ExperimentRun/dcid.598fa91f-8997-4063-b931-1f2d8acdf95a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=K0i2RQECSM7qtPCi%2BfTZg964QGsAWpJiMlRMrkplSdc%3D&st=2021-03-01T20%3A16%3A07Z&se=2021-03-02T04%3A26%3A07Z&sp=r'},
#  'submittedBy': 'Chad B'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
